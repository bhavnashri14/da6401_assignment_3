# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import matplotlib.pyplot as plt
# %run /content/drive/MyDrive/da6401_assignment_3/lr_scheduler.py

# %%
import os
os.environ["WANDB_MODE"] = "online"

import wandb
wandb.login()
# Out:
# /usr/local/lib/python3.12/dist-packages/notebook/notebookapp.py:191: SyntaxWarning: invalid escape sequence '\/'
#   | |_| | '_ \/ _` / _` |  _/ -_)
# wandb: (1) Create a W&B account
# wandb: (2) Use an existing W&B account
# wandb: (3) Don't visualize my results
# wandb: Enter your choice:
#  2
# wandb: You chose 'Use an existing W&B account'
# wandb: Logging into https://api.wandb.ai. (Learn how to deploy a W&B server locally: https://wandb.me/wandb-server)
# wandb: Create a new API key at: https://wandb.ai/authorize?ref=models
# wandb: Store your API key securely and do not share it.
# wandb: Paste your API key and hit enter:
#  ··········
# wandb: No netrc file found, creating one.
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# wandb: Currently logged in as: me21b044 (me21b044-iit-madras-foundation) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# True

# %%
# !python -m spacy download de_core_news_sm
# !python -m spacy download en_core_web_sm
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.6/14.6 MB 96.9 MB/s eta 0:00:00
# ...
# ✔ Download and installation successful
# You can now load the package via spacy.load('de_core_news_sm')
# ⚠ Restart to reload dependencies
# If you are in a Jupyter or Colab notebook, you may need to restart Python in
# order to load all the package's dependencies. You can do this by selecting the
# 'Restart kernel' or 'Restart runtime' option.
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.8/12.8 MB 99.1 MB/s eta 0:00:00
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')
# ⚠ Restart to reload dependencies
# If you are in a Jupyter or Colab notebook, you may need to restart Python in
# order to load all the package's dependencies. You can do this by selecting the
# 'Restart kernel' or 'Restart runtime' option.

# %%
# !python /content/drive/MyDrive/da6401_assignment_3/train.py
# Out:
# README.md: 1.15kB [00:00, 2.62MB/s]
# ...
# train.jsonl: 4.60MB [00:00, 58.4MB/s]
# val.jsonl: 164kB [00:00, 67.7MB/s]
# test.jsonl: 156kB [00:00, 21.3MB/s]
# Generating train split: 100% 29000/29000 [00:00<00:00, 343866.36 examples/s]
# Generating validation split: 100% 1014/1014 [00:00<00:00, 221881.48 examples/s]
# Generating test split: 100% 1000/1000 [00:00<00:00, 287931.90 examples/s]
#
# === EXP 2.1: Noam vs Fixed LR ===
# wandb: [wandb.login()] Loaded credentials for https://api.wandb.ai from /root/.netrc.
# wandb: Currently logged in as: me21b044 (me21b044-iit-madras-foundation) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# wandb: WARNING Using a boolean value for 'reinit' is deprecated. Use 'return_previous' or 'finish_previous' instead.
# wandb: ⢿ Waiting for wandb.init()...
# wandb: ⣻ Waiting for wandb.init()...
# wandb: Tracking run with wandb version 0.26.1
# wandb: Run data is saved locally in /content/wandb/run-20260518_124821-3g57q1i0
# ...

# %%
# !python /content/drive/MyDrive/da6401_assignment_3/train.py
# Out:
# README.md: 1.15kB [00:00, 4.76MB/s]
# ...
# train.jsonl: 4.60MB [00:00, 130MB/s]
# val.jsonl: 164kB [00:00, 148MB/s]
# test.jsonl: 156kB [00:00, 112MB/s]
# Generating train split: 100% 29000/29000 [00:00<00:00, 636218.60 examples/s]
# Generating validation split: 100% 1014/1014 [00:00<00:00, 435136.51 examples/s]
# Generating test split: 100% 1000/1000 [00:00<00:00, 489588.42 examples/s]
#
# === EXP 2.2: With vs Without Scaling ===
# wandb: [wandb.login()] Loaded credentials for https://api.wandb.ai from /root/.netrc.
# wandb: Currently logged in as: me21b044 (me21b044-iit-madras-foundation) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# wandb: WARNING Using a boolean value for 'reinit' is deprecated. Use 'return_previous' or 'finish_previous' instead.
# wandb: ⢿ Waiting for wandb.init()...
# wandb: ⣻ Waiting for wandb.init()...
# wandb: ⣽ Waiting for wandb.init()...
# wandb: ⣾ Waiting for wandb.init()...
# wandb: ⣷ setting up run k3d48nro (0.5s)
# ...

# %%
# !python /content/drive/MyDrive/da6401_assignment_3/train.py
# Out:
# ...
#
# === EXP 2.3: Attention Heatmaps ===
# wandb: [wandb.login()] Loaded credentials for https://api.wandb.ai from /root/.netrc.
# wandb: Currently logged in as: me21b044 (me21b044-iit-madras-foundation) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# wandb: WARNING Using a boolean value for 'reinit' is deprecated. Use 'return_previous' or 'finish_previous' instead.
# wandb: ⢿ setting up run z6rq5av9 (0.0s)
# wandb: ⣻ setting up run z6rq5av9 (0.0s)
# wandb: ⣽ setting up run z6rq5av9 (0.0s)
# wandb: ⣾ setting up run z6rq5av9 (0.0s)
# wandb: ⣷ setting up run z6rq5av9 (0.5s)
# wandb: ⣯ setting up run z6rq5av9 (0.5s)
# wandb: ⣟ setting up run z6rq5av9 (0.5s)
# wandb: ⡿ setting up run z6rq5av9 (0.5s)
# wandb: ⢿ setting up run z6rq5av9 (0.5s)
# wandb: ⣻ setting up run z6rq5av9 (1.0s)
# wandb: ⣽ setting up run z6rq5av9 (1.0s)
# wandb: ⣾ setting up run z6rq5av9 (1.0s)
# wandb: ⣷ setting up run z6rq5av9 (1.0s)
# wandb: ⣯ setting up run z6rq5av9 (1.0s)
# ...

# %%
# !python /content/drive/MyDrive/da6401_assignment_3/train.py
# Out:
# ...
# README.md: 1.15kB [00:00, 2.68MB/s]
# train.jsonl: 4.60MB [00:00, 100MB/s]
# val.jsonl: 164kB [00:00, 109MB/s]
# test.jsonl: 156kB [00:00, 107MB/s]
# Generating train split: 100% 29000/29000 [00:00<00:00, 663543.46 examples/s]
# Generating validation split: 100% 1014/1014 [00:00<00:00, 471353.68 examples/s]
# Generating test split: 100% 1000/1000 [00:00<00:00, 498076.71 examples/s]
#
# === EXP 2.4: Sinusoidal vs Learned PE ===
# wandb: [wandb.login()] Loaded credentials for https://api.wandb.ai from /root/.netrc.
# wandb: Currently logged in as: me21b044 (me21b044-iit-madras-foundation) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# wandb: WARNING Using a boolean value for 'reinit' is deprecated. Use 'return_previous' or 'finish_previous' instead.
# wandb: ⢿ Waiting for wandb.init()...
# wandb: ⣻ Waiting for wandb.init()...
# wandb: Tracking run with wandb version 0.26.1
# wandb: Run data is saved locally in /content/wandb/run-20260518_092521-rj5qotx7
# ...

# %%
# !python /content/drive/MyDrive/da6401_assignment_3/train.py
# Out:
# ...
#
# === EXP 2.5: Label Smoothing ===
# wandb: [wandb.login()] Loaded credentials for https://api.wandb.ai from /root/.netrc.
# wandb: Currently logged in as: me21b044 (me21b044-iit-madras-foundation) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# wandb: WARNING Using a boolean value for 'reinit' is deprecated. Use 'return_previous' or 'finish_previous' instead.
# wandb: ⢿ setting up run hcb583ix (0.0s)
# wandb: ⣻ setting up run hcb583ix (0.0s)
# wandb: ⣽ setting up run hcb583ix (0.0s)
# wandb: Tracking run with wandb version 0.26.1
# wandb: Run data is saved locally in /content/wandb/run-20260518_110857-hcb583ix
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run 2.5_smoothing_0.1
# wandb: ⭐️ View project at https://wandb.ai/me21b044-iit-madras-foundation/ASSIGNMENT%203
# wandb: 🚀 View run at https://wandb.ai/me21b044-iit-madras-foundation/ASSIGNMENT%203/runs/hcb583ix
# [2.5|smoothing=0.1] Epoch 0 | Train 6.1994 | Confidence 0.0770
# ...
